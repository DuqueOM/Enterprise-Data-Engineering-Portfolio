# %% [markdown]
# # EDA — dataset PYME QA\nEste notebook contiene análisis básicos: conteo por longitud, top tokens y ejemplos.

# %%
import pandas as pd

df = pd.read_json('data/processed/faqs_clean.jsonl', lines=True)
print('Rows:', len(df))
print(df.head().to_dict(orient='records')[:2])
